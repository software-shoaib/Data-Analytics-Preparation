# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step1: Load Data
# ### Step2: Separate input and output features
# ### Step3: Break the data into training data and testing data
# ### Step4: Selecting the algorithm /model
# ### Step5: Training the model
# ### Step6: Evaluating the model
# ### Step7: Predict using model
# ### Step8: Study model performance Error

# %%
data1 = pd.read_csv("weight-height.csv")

# %%
data = data1[['Height', 'Weight']]

# %%
data
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 9995  66.172652  136.777454
# 9996  67.067155  170.867906
# 9997  63.867992  128.475319
# 9998  69.034243  163.852461
# 9999  61.944246  113.649103
#
# [10000 rows x 2 columns]

# %%
height = data.Height
weight = data.Weight

# %%
plt.figure(figsize=(40,40))
plt.scatter(height,weight)

# %%
X = data[['Height']]
y = data[['Weight']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
y_train
# Out:
#           Weight
# 2967  187.779075
# 700   187.812062
# 3481  214.787698
# 1621  210.821194
# 800   204.937760
# ...          ...
# 9225   97.263881
# 4859  174.156893
# 3264  162.475957
# 9845  136.783022
# 2732  188.450674
#
# [7500 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create and fit the linear regression model
height_weight_regressor = LinearRegression()
height_weight_regressor.fit(X_train, y_train)
y_pred_train = height_weight_regressor.predict(X_train)

# Flatten the y_train and y_pred_train arrays
y_train_flat = y_train['Weight'].values.flatten()
y_pred_train_flat = y_pred_train.flatten()

# Create the DataFrame with flattened arrays
df = pd.DataFrame({'y_train': y_train_flat, 'y_pred_train': y_pred_train_flat})

# Now df contains the flattened arrays in a DataFrame

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train_flat,y_pred_train_flat)
# Out:
# 148.5696166325645

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train_flat,y_pred_train_flat)
# Out:
# 0.85534320254092

# %%
height_weight_regressor.coef_
# Out:
# array([[7.71833809]])

# %%
height_weight_regressor.intercept_
# Out:
# array([-350.84158095])

# %%
user_height = float(input("enter your height, I will tell your age: "))
print(f"your according to your height {user_height} your weight is {height_weight_regressor.predict([[user_height]])}")
# Out:
# enter your height, I will tell your age: 14
# your according to your height 14.0 your weight is [[-242.7848477]]
# C:\Python\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data1.head
# Out:
# <bound method NDFrame.head of       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]>

# %%
data1.Gender.value_counts()
# Out:
# Male      5000
# Female    5000
# Name: Gender, dtype: int64

# %% [markdown]
# ###labeling data as 1 = male and 0= female

# %%
data1.Gender = data1.Gender.apply(lambda x : 1 if x=='Male' else 0 )

# %%
data1.Gender.value_counts()
# Out:
# 1    5000
# 0    5000
# Name: Gender, dtype: int64

# %%
data1.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
data1.sample(10)
# Out:
#       Gender     Height      Weight
# 9129       0  66.313844  139.141991
# 1350       1  73.573284  207.209461
# 310        1  74.223063  223.308040
# 8138       0  63.213963  142.566080
# 8371       0  65.289259  140.055483
# 9610       0  61.432039  131.424789
# 1106       1  67.323714  157.029935
# 212        1  72.394480  208.436509
# 4349       1  69.196983  194.257748
# 4806       1  72.900651  222.509055

# %%
X = data1[['Gender', 'Height']]
y =data[['Weight']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
mul_regression = LinearRegression()

# %%
mul_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = mul_regression.predict(X_train)

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 99.53818508709486

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.9030833126856689

# %%
user_height = float(input("Ernter your height, i will tell you your weight"))
user_gender = int(input("Enter your gender for male input 1 and for female input 0"))
print(f"your according to your height {user_height} your weight is {mul_regression.predict([[user_gender,user_height]])}")
# Out:
# Ernter your height, i will tell you your weight44
# Enter your gender for male input 1 and for female input 02
# your according to your height 44.0 your weight is [[57.05829105]]
# C:\Python\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
