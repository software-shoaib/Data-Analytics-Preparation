# %% [markdown]
# <a href="https://colab.research.google.com/github/software-shoaib/LinearRegression_Model_Practice/blob/main/prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://en.wikipedia.org/wiki/Shoaib_Akhtar"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# %%
# Parse the html content
soup = BeautifulSoup(html_content, "lxml")

# %%
print(soup.prettify()) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Shoaib Akhtar - Wikipedia
#   </title>
#   <script>
# ...

# %%
tag_object = soup.title()
title
# Out:
# []

# %%
tag_object = soup.span
tag_object
# Out:
# <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>

# %%
child = tag_object.attrs

# %%
child
# Out:
# {'class': ['vector-icon', 'mw-ui-icon-menu', 'mw-ui-icon-wikimedia-menu']}

# %%
tag_object.string

# %%
li = soup.li
li
# Out:
# <li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li>

# %%
tables = soup.find_all(name='table')
all_td = soup.table.find_all(name = 'td')
all_td
# Out:
# [<td class="infobox-image" colspan="2"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Khizer_Ahmed_and_mentor_Shoaib_Akhtar_(cropped).jpg"><img class="mw-file-element" data-file-height="1930" data-file-width="1762" decoding="async" height="241" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/220px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/330px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/440px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg 2x" width="220"/></a></span><div class="infobox-caption">Shoaib in 2018</div></td>,
# ...

# %%
all_td.sort
# Out:
# <function ResultSet.sort(*, key=None, reverse=False)>

# %%
all_td
# Out:
# [<td class="infobox-image" colspan="2"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Khizer_Ahmed_and_mentor_Shoaib_Akhtar_(cropped).jpg"><img class="mw-file-element" data-file-height="1930" data-file-width="1762" decoding="async" height="241" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/220px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/330px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg/440px-Khizer_Ahmed_and_mentor_Shoaib_Akhtar_%28cropped%29.jpg 2x" width="220"/></a></span><div class="infobox-caption">Shoaib in 2018</div></td>,
# ...
